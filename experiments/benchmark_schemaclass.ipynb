# %% [markdown]
# # Benchmark Results
#
# For object creation and selecting, using schema objects increases time by 2-3x. This means using object-oriented approach incurs a huge cost over using dictionaries.

# %%
import sys
sys.path.append('..')
import doctable
import dataclasses
import functools
import tempfile
import random
import copy

# %% [markdown]
# ## Basic Benchmark: Schema Object VS Raw Dictionaries

# %%
@doctable.schema
class MyObjSmall:
    __slots__ = []
    id: int = doctable.Col()
    name: str = doctable.Col()

@doctable.schema
class MyObjBig:
    __slots__ = []
    id: int = doctable.Col()
    name: str = doctable.Col()
    extra1: str = doctable.Col()
    extra2: str = doctable.Col()
    extra3: str = doctable.Col()
    extra4: str = doctable.Col()
    extra5: str = doctable.Col()

# %%
def make_test_dt(SchemaClass, tmpdir) -> doctable.DocTable:
    dt_small = doctable.DocTable(
        schema=SchemaClass,
        target = f'{tmpdir}/{SchemaClass}_test.db',
        new_db = True,
    )
    return dt_small
def runtest_obj(n: int = 100):
    print(f'=== start OBJECT test: {n=} ================')
    with tempfile.TemporaryDirectory() as tmpdir:
        dt_small = make_test_dt(MyObjSmall, tmpdir)
        print(f'construct {n} objects')
        # %timeit [MyObjSmall(i, f'name_{i}') for i in range(n)]
        test_objs = [MyObjSmall(i, f'name_{i}') for i in range(n)]
        print(f'insert objects')
        # %time dt_small.q.insert_multi(test_objs)
        print(f'select objects')
        # %timeit dt_small.q.select()

def runtest_raw(n: int = 100):
    print(f'=== start RAW test: {n=} ================')
    with tempfile.TemporaryDirectory() as tmpdir:
        dt_small = make_test_dt(MyObjSmall, tmpdir)
        print(f'construct {n} objects')
        # %timeit [{'id': i, 'name': f'name_{i}'} for i in range(n)]
        test_objs = [{'id': i, 'name': f'name_{i}'} for i in range(n)]
        print(f'insert objects')
        # %time dt_small.q.insert_multi_raw(test_objs)
        print(f'select objects')
        # %timeit dt_small.q.select_raw()

for n in [100, 1000, 10000, 100000, 1000000]:
    print(f'================== {n=}=============================')
    runtest_obj(n)
    runtest_raw(n)
# Out:
# ================== n=100=============================
# === start test: n=100 ================
# construct 100 objects
# 66.6 µs ± 76.5 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# insert objects
# CPU times: user 0 ns, sys: 1.65 ms, total: 1.65 ms
# Wall time: 3.77 ms
# select objects
# 919 µs ± 5.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# === start test: n=100 ================
# construct 100 objects
# 21.5 µs ± 100 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# insert objects
# CPU times: user 1.5 ms, sys: 0 ns, total: 1.5 ms
# Wall time: 8.28 ms
# select objects
# 405 µs ± 136 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# ================== n=1000=============================
# === start test: n=1000 ================
# construct 1000 objects
# 659 µs ± 454 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# insert objects
# CPU times: user 5.24 ms, sys: 0 ns, total: 5.24 ms
# Wall time: 8.58 ms
# select objects
# 5.92 ms ± 15.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# === start test: n=1000 ================
# construct 1000 objects
# 235 µs ± 195 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# insert objects
# CPU times: user 3.69 ms, sys: 35 µs, total: 3.72 ms
# Wall time: 11.9 ms
# select objects
# 1.11 ms ± 204 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# ================== n=10000=============================
# === start test: n=10000 ================
# construct 10000 objects
# 6.97 ms ± 1.75 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# insert objects
# CPU times: user 93.7 ms, sys: 52 µs, total: 93.8 ms
# Wall time: 97.7 ms
# select objects
# 56.8 ms ± 106 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# === start test: n=10000 ================
# construct 10000 objects
# 2.4 ms ± 515 ns per loop (mean ± std. dev. of 7 runs, 100 loops each)
# insert objects
# CPU times: user 26 ms, sys: 0 ns, total: 26 ms
# Wall time: 35.8 ms
# select objects
# 8.28 ms ± 6.59 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ================== n=100000=============================
# === start test: n=100000 ================
# construct 100000 objects
# 72.6 ms ± 31.7 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# insert objects
# CPU times: user 482 ms, sys: 44 ms, total: 526 ms
# Wall time: 544 ms
# select objects
# 585 ms ± 3.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# === start test: n=100000 ================
# construct 100000 objects
# 38.3 ms ± 31.5 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# insert objects
# CPU times: user 312 ms, sys: 8.15 ms, total: 320 ms
# Wall time: 336 ms
# select objects
# 91 ms ± 85.5 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ================== n=1000000=============================
# === start test: n=1000000 ================
# construct 1000000 objects
# 762 ms ± 3.86 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# insert objects
# CPU times: user 4.22 s, sys: 256 ms, total: 4.48 s
# Wall time: 4.54 s
# select objects
# 5.57 s ± 240 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# === start test: n=1000000 ================
# construct 1000000 objects
# 390 ms ± 209 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# insert objects
# CPU times: user 2.87 s, sys: 128 ms, total: 3 s
# Wall time: 3.1 s
# select objects
# 841 ms ± 2.21 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
